# %%
import numpy as np

# %%
def is_prime(x):

  if x>=2:

    for k in np.arange(2, x):
      if x % k == 0:
        return False
    return True
  else:
    return False

# %%
[k for k in np.arange(2,600851475143) if (600851475143 % k == 0) and is_prime(k)]
